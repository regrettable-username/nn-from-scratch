# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_train = pd.read_csv('train.csv')
df_line = pd.read_csv('line.csv')
df_fitted = pd.read_csv('fitted_line.csv')

# %%
plt.figure(figsize=(15, 10))
ax = plt.axes()
ax.scatter(df_train['x'], df_train['y'])

bias = df_line['bias'][0]
slope = df_line['slope'][0]

fitted_bias = df_fitted['bias'][0]
fitted_slope = df_fitted['slope'][0]

# print(bias[0])
# print(slope.size)
x_vals = np.linspace(0, 6, 15)
y_vals = slope * x_vals + bias

fitted_y = fitted_slope * x_vals + fitted_bias
print(fitted_y)
ax.plot(x_vals, y_vals, color='red')
ax.plot(x_vals, fitted_y, color='blue')

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')

plt.show()
# Out:
# [0.134588 0.609488 1.084388 1.559288 2.034188 2.509088 2.983988 3.458888
#  3.933788 4.408688 4.883588 5.358488 5.833388 6.308288 6.783188]
