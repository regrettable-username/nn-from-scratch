# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_train = pd.read_csv('train.csv')
df_line = pd.read_csv('line.csv')
df_fitted = pd.read_csv('fitted_line.csv')

# %%
plt.figure(figsize=(15, 10))
ax = plt.axes()
ax.scatter(df_train['x'], df_train['y'])

bias = df_line['bias'][0]
slope = df_line['slope'][0]

fitted_bias = df_fitted['bias'][0]
fitted_slope = df_fitted['slope'][0]

# print(bias[0])
# print(slope.size)
x_vals = np.linspace(0, 6, 15)
y_vals = slope * x_vals + bias

fitted_y = fitted_slope * x_vals + fitted_bias
print(fitted_y)
ax.plot(x_vals, y_vals, color='red')
ax.plot(x_vals, fitted_y, color='blue')

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')

plt.show()
# Out:
# [ 1.          0.91630171  0.83260343  0.74890514  0.66520686  0.58150857
#   0.49781029  0.414112    0.33041371  0.24671543  0.16301714  0.07931886
#  -0.00437943 -0.08807771 -0.171776  ]
